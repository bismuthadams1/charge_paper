# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Out:
#            ZINC_ID      MWT  LogP  Desolv_apolar  Desolv_polar  HBD  HBA  \
# 0     ZINC00000018  212.318  2.00           5.91         -8.69    1    3
# 1     ZINC00000036  151.141  0.37           2.61        -46.53    1    3
# 2     ZINC00000053  179.151  1.43           5.65        -56.66    0    4
# 3     ZINC00000061  213.664 -0.42           3.92        -52.87    3    3
# 4     ZINC00000070  300.721  4.53          -0.61        -46.43    0    4
# ...            ...      ...   ...            ...           ...  ...  ...
# 3175  ZINC15848267  392.467  2.09           2.69        -17.09    3    5
# 3176  ZINC15848268  392.467  2.09           3.20        -16.23    3    5
# 3177  ZINC15848269  392.467  2.09           2.89        -14.46    3    5
# 3178  ZINC15848271  312.864  5.08          13.35        -41.48    1    1
# 3179  ZINC15880092  137.206  0.73           3.40        -38.31    2    2
#
#       tPSA  Charge  NRB                                             SMILES
# ...

# %%
pd.read_csv('cnsdrugs/data/EPA-DSSTOX/fda_prop.xls',sep='\t')
